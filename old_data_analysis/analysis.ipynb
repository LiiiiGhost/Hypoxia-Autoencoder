# %%
import pandas as pd

df = pd.read_csv('rnaseq_s1.tsv', sep='\t')
df = pd.merge(df, pd.read_csv('file_to_case.tsv', sep='\t'), on='file_id', how='left')
df = pd.merge(df, pd.read_csv('clinical.tsv', sep='\t'), on='case_id', how='left')

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

arr =  ['vital_status',
 'ajcc_clinical_m',
 'ajcc_clinical_n',
 'ajcc_clinical_stage',
 'ajcc_clinical_t',
 'ajcc_pathologic_m',
 'ajcc_pathologic_n',
 'ajcc_pathologic_stage',
 'ajcc_pathologic_t',
 'ajcc_staging_system_edition',
 'icd_10_code',
 'morphology',
 'primary_diagnosis',
 'prior_malignancy',
 'prior_treatment',
 'site_of_resection_or_biopsy',
 'synchronous_malignancy',
 'tissue_or_organ_of_origin',
 'treatment_or_therapy',
 'treatment_type',
 'treatment_or_therapy_2',
 'treatment_type_2',
 'alcohol_history']

for i in arr:
    X = df.drop(columns=['file_id'] + list(pd.read_csv('clinical.tsv', sep='\t').columns)).apply(pd.to_numeric)
    y = df[i].map({value: index for index, value in enumerate(df[i].unique())})

    X = MinMaxScaler().fit_transform(X)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

    classifier = RandomForestClassifier()
    classifier.fit(X_train, y_train)
    y_pred = classifier.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(i, "Accuracy:", accuracy)
# Out:
# vital_status Accuracy: 0.5575221238938053
# ajcc_clinical_m Accuracy: 0.9734513274336283
# ajcc_clinical_n Accuracy: 0.40707964601769914
# ajcc_clinical_stage Accuracy: 0.4778761061946903
# ajcc_clinical_t Accuracy: 0.3274336283185841
# ajcc_pathologic_m Accuracy: 0.5929203539823009
# ajcc_pathologic_n Accuracy: 0.2831858407079646
# ajcc_pathologic_stage Accuracy: 0.4424778761061947
# ajcc_pathologic_t Accuracy: 0.30973451327433627
# ajcc_staging_system_edition Accuracy: 0.7433628318584071
# icd_10_code Accuracy: 0.2743362831858407
# morphology Accuracy: 0.8495575221238938
# primary_diagnosis Accuracy: 0.8230088495575221
# prior_malignancy Accuracy: 0.9557522123893806
# prior_treatment Accuracy: 0.9734513274336283
# site_of_resection_or_biopsy Accuracy: 0.36283185840707965
# synchronous_malignancy Accuracy: 0.9380530973451328
# tissue_or_organ_of_origin Accuracy: 0.39823008849557523
# treatment_or_therapy Accuracy: 0.5132743362831859
# treatment_type Accuracy: 0.48672566371681414
# treatment_or_therapy_2 Accuracy: 0.415929203539823
# treatment_type_2 Accuracy: 0.5309734513274337
# alcohol_history Accuracy: 0.584070796460177

# %%
import numpy as np
from keras.models import Model
from keras.layers import Input, Dense
import matplotlib.pyplot as plt

i = 'vital_status'
X = df.drop(columns=['file_id'] + list(pd.read_csv('clinical.tsv', sep='\t').columns)).apply(pd.to_numeric)
y = df['vital_status'].map({'Alive': True, 'Dead': False})
X = MinMaxScaler().fit_transform(X)

input_img = Input(shape=(23,))
encoded = Dense(20, activation='relu')(input_img)
encoded = Dense(15, activation='relu')(encoded)
encoded = Dense(2, activation='relu')(encoded)
decoded = Dense(15, activation='relu')(encoded)
decoded = Dense(20, activation='relu')(decoded)
decoded = Dense(23, activation='sigmoid')(decoded)

autoencoder = Model(input_img, decoded)
encoder = Model(input_img, encoded)
decoder = Model(encoded, decoded)

autoencoder.compile(optimizer='adam', loss='mean_squared_error')

history = autoencoder.fit(X, X,
                epochs=120,
                batch_size=256,
                shuffle=True,
                validation_split=0.2
)

encoded_imgs = encoder.predict(X)

plt.scatter(encoded_imgs[:, 0], encoded_imgs[:, 1], c=y, cmap='bwr', s=1)
plt.show()
# Out:
# Epoch 1/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 187ms/step - loss: 0.1253 - val_loss: 0.1247
# Epoch 2/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1247 - val_loss: 0.1243
# Epoch 3/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1246 - val_loss: 0.1238
# Epoch 4/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1245 - val_loss: 0.1233
# Epoch 5/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1238 - val_loss: 0.1227
# Epoch 6/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1235 - val_loss: 0.1221
# Epoch 7/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1226 - val_loss: 0.1214
# Epoch 8/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1218 - val_loss: 0.1206
# Epoch 9/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1209 - val_loss: 0.1197
# Epoch 10/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1194 - val_loss: 0.1188
# Epoch 11/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1189 - val_loss: 0.1177
# Epoch 12/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1175 - val_loss: 0.1166
# Epoch 13/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1163 - val_loss: 0.1155
# Epoch 14/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1160 - val_loss: 0.1142
# Epoch 15/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1148 - val_loss: 0.1129
# Epoch 16/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1127 - val_loss: 0.1115
# Epoch 17/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1113 - val_loss: 0.1098
# Epoch 18/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1105 - val_loss: 0.1080
# Epoch 19/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1081 - val_loss: 0.1060
# Epoch 20/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1061 - val_loss: 0.1038
# Epoch 21/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1034 - val_loss: 0.1015
# Epoch 22/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1010 - val_loss: 0.0990
# Epoch 23/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0988 - val_loss: 0.0963
# Epoch 24/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0959 - val_loss: 0.0934
# Epoch 25/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0934 - val_loss: 0.0903
# Epoch 26/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0898 - val_loss: 0.0870
# Epoch 27/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0868 - val_loss: 0.0835
# Epoch 28/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0826 - val_loss: 0.0798
# Epoch 29/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0789 - val_loss: 0.0759
# Epoch 30/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0756 - val_loss: 0.0719
# Epoch 31/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0714 - val_loss: 0.0678
# Epoch 32/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0668 - val_loss: 0.0636
# Epoch 33/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0630 - val_loss: 0.0594
# Epoch 34/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0586 - val_loss: 0.0553
# Epoch 35/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0543 - val_loss: 0.0514
# Epoch 36/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0512 - val_loss: 0.0476
# Epoch 37/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0476 - val_loss: 0.0442
# Epoch 38/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0435 - val_loss: 0.0410
# Epoch 39/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0405 - val_loss: 0.0382
# Epoch 40/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0381 - val_loss: 0.0358
# Epoch 41/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0357 - val_loss: 0.0338
# Epoch 42/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0338 - val_loss: 0.0321
# Epoch 43/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0320 - val_loss: 0.0307
# Epoch 44/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0310 - val_loss: 0.0297
# Epoch 45/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0299 - val_loss: 0.0288
# Epoch 46/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0292 - val_loss: 0.0282
# Epoch 47/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0286 - val_loss: 0.0277
# Epoch 48/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0283 - val_loss: 0.0274
# Epoch 49/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0279 - val_loss: 0.0271
# Epoch 50/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0276 - val_loss: 0.0268
# Epoch 51/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0280 - val_loss: 0.0266
# Epoch 52/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0274 - val_loss: 0.0264
# Epoch 53/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0270 - val_loss: 0.0261
# Epoch 54/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0270 - val_loss: 0.0259
# Epoch 55/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0267 - val_loss: 0.0257
# Epoch 56/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0260 - val_loss: 0.0255
# Epoch 57/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0264 - val_loss: 0.0253
# Epoch 58/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0258 - val_loss: 0.0251
# Epoch 59/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0257 - val_loss: 0.0249
# Epoch 60/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0258 - val_loss: 0.0247
# Epoch 61/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0259 - val_loss: 0.0246
# Epoch 62/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0251 - val_loss: 0.0244
# Epoch 63/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0250 - val_loss: 0.0243
# Epoch 64/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0252 - val_loss: 0.0242
# Epoch 65/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0250 - val_loss: 0.0240
# Epoch 66/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0245 - val_loss: 0.0239
# Epoch 67/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0243 - val_loss: 0.0238
# Epoch 68/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0242 - val_loss: 0.0236
# Epoch 69/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0241 - val_loss: 0.0235
# Epoch 70/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0243 - val_loss: 0.0233
# Epoch 71/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0241 - val_loss: 0.0232
# Epoch 72/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0238 - val_loss: 0.0230
# Epoch 73/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0237 - val_loss: 0.0229
# Epoch 74/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0236 - val_loss: 0.0228
# Epoch 75/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0234 - val_loss: 0.0226
# Epoch 76/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0237 - val_loss: 0.0225
# Epoch 77/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0230 - val_loss: 0.0224
# Epoch 78/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0231 - val_loss: 0.0222
# Epoch 79/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0229 - val_loss: 0.0221
# Epoch 80/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0230 - val_loss: 0.0220
# Epoch 81/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0230 - val_loss: 0.0218
# Epoch 82/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0231 - val_loss: 0.0217
# Epoch 83/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0224 - val_loss: 0.0216
# Epoch 84/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0225 - val_loss: 0.0214
# Epoch 85/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0225 - val_loss: 0.0213
# Epoch 86/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0222 - val_loss: 0.0212
# Epoch 87/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0221 - val_loss: 0.0210
# Epoch 88/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0216 - val_loss: 0.0209
# Epoch 89/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0219 - val_loss: 0.0207
# Epoch 90/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0215 - val_loss: 0.0206
# Epoch 91/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0214 - val_loss: 0.0204
# Epoch 92/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0211 - val_loss: 0.0203
# Epoch 93/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0209 - val_loss: 0.0201
# Epoch 94/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0209 - val_loss: 0.0199
# Epoch 95/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0207 - val_loss: 0.0197
# Epoch 96/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0203 - val_loss: 0.0194
# Epoch 97/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0201 - val_loss: 0.0192
# Epoch 98/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0197 - val_loss: 0.0190
# Epoch 99/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0198 - val_loss: 0.0188
# Epoch 100/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0194 - val_loss: 0.0186
# Epoch 101/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0191 - val_loss: 0.0184
# Epoch 102/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0192 - val_loss: 0.0181
# Epoch 103/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0191 - val_loss: 0.0179
# Epoch 104/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0186 - val_loss: 0.0176
# Epoch 105/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0182 - val_loss: 0.0174
# Epoch 106/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0179 - val_loss: 0.0171
# Epoch 107/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0179 - val_loss: 0.0168
# Epoch 108/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0175 - val_loss: 0.0166
# Epoch 109/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0173 - val_loss: 0.0163
# Epoch 110/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0172 - val_loss: 0.0161
# Epoch 111/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0169 - val_loss: 0.0158
# Epoch 112/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0166 - val_loss: 0.0156
# Epoch 113/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0162 - val_loss: 0.0154
# Epoch 114/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0161 - val_loss: 0.0152
# Epoch 115/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0159 - val_loss: 0.0150
# Epoch 116/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0157 - val_loss: 0.0148
# Epoch 117/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0157 - val_loss: 0.0146
# Epoch 118/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0154 - val_loss: 0.0145
# Epoch 119/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0152 - val_loss: 0.0143
# Epoch 120/120
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0152 - val_loss: 0.0142
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
import pandas as pd

df = pd.read_csv('rnaseq_s2.tsv', sep='\t')
df = pd.merge(df, pd.read_csv('file_to_case.tsv', sep='\t'), on='file_id', how='left')
df = pd.merge(df, pd.read_csv('clinical.tsv', sep='\t'), on='case_id', how='left')

import numpy as np
from keras.models import Model
from keras.layers import Input, Dense
import matplotlib.pyplot as plt

i = 'vital_status'
X = df.drop(columns=['file_id'] + list(pd.read_csv('clinical.tsv', sep='\t').columns)).apply(pd.to_numeric)
y = df['vital_status'].map({'Alive': True, 'Dead': False})
X = MinMaxScaler().fit_transform(X)

input_img = Input(shape=(27,))
encoded = Dense(20, activation='relu')(input_img)
encoded = Dense(10, activation='relu')(encoded)
encoded = Dense(2, activation='relu')(encoded)
decoded = Dense(10, activation='relu')(encoded)
decoded = Dense(27, activation='sigmoid')(decoded)

autoencoder = Model(input_img, decoded)
encoder = Model(input_img, encoded)
decoder = Model(encoded, decoded)

autoencoder.compile(optimizer='adam', loss='mean_squared_error')

history = autoencoder.fit(X, X,
                epochs=120,
                batch_size=256,
                shuffle=True,
                validation_split=0.2,
                verbose=0
)

encoded_imgs = encoder.predict(X)

plt.scatter(encoded_imgs[:, 0], encoded_imgs[:, 1], c=y, cmap='bwr', s=1)
plt.show()
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
import pandas as pd

df = pd.read_csv('rnaseq_s1_s2.tsv', sep='\t')
df = pd.merge(df, pd.read_csv('file_to_case.tsv', sep='\t'), on='file_id', how='left')
df = pd.merge(df, pd.read_csv('clinical.tsv', sep='\t'), on='case_id', how='left')

import numpy as np
from keras.models import Model
from keras.layers import Input, Dense
import matplotlib.pyplot as plt

i = 'vital_status'
X = df.drop(columns=['file_id'] + list(pd.read_csv('clinical.tsv', sep='\t').columns)).apply(pd.to_numeric)
y = df['vital_status'].map({'Alive': True, 'Dead': False})
X = MinMaxScaler().fit_transform(X)

input_img = Input(shape=(50,))
encoded = Dense(30, activation='relu')(input_img)
encoded = Dense(15, activation='relu')(encoded)
encoded = Dense(2, activation='relu')(encoded)
decoded = Dense(15, activation='relu')(encoded)
decoded = Dense(30, activation='relu')(decoded)
decoded = Dense(50, activation='sigmoid')(decoded)

autoencoder = Model(input_img, decoded)
encoder = Model(input_img, encoded)
decoder = Model(encoded, decoded)

autoencoder.compile(optimizer='adam', loss='mean_squared_error')

history = autoencoder.fit(X, X,
                epochs=120,
                batch_size=256,
                shuffle=True,
                validation_split=0.2,
                verbose=0
)

encoded_imgs = encoder.predict(X)

plt.scatter(encoded_imgs[:, 0], encoded_imgs[:, 1], c=y, cmap='bwr', s=1)
plt.show()
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# case_id                         ID
# case_submitter_id               ID
# age_at_index                    NUM
# days_to_birth                   NUM (age)
# days_to_death                   NUM (null if alive)
# ethnicity
# gender
# race
# vital_status                    CAT
# year_of_birth
# year_of_death
# age_at_diagnosis
# ajcc_clinical_m                 M0: 495, MX: 21, M1: 6, '--, 5 (imbalance)
# ajcc_clinical_n                 N0: 245, N1: 85, N2b: 85, N2c: 45, N2: 19, NX: 18, N2a: 17, N3: 9, '-- 4 (imbalance)
# ajcc_clinical_stage
# ajcc_clinical_t
# ajcc_pathologic_m
# ajcc_pathologic_n
# ajcc_pathologic_stage
# ajcc_pathologic_t
# ajcc_staging_system_edition
# days_to_last_follow_up
# icd_10_code
# morphology
# primary_diagnosis
# prior_malignancy
# prior_treatment
# site_of_resection_or_biopsy
# synchronous_malignancy
# tissue_or_organ_of_origin
# year_of_diagnosis
# treatment_or_therapy
# treatment_type
# treatment_or_therapy_2
# treatment_type_2
# alcohol_history
# cigarettes_per_day
# pack_years_smoked
# years_smoked
#
# vital_status Accuracy: 0.5486725663716814
# ajcc_clinical_m Accuracy: 0.9646017699115044
# ajcc_clinical_n Accuracy: 0.4778761061946903
# ajcc_clinical_stage Accuracy: 0.49557522123893805
# ajcc_clinical_t Accuracy: 0.30973451327433627
# ajcc_pathologic_m Accuracy: 0.6283185840707964
# ajcc_pathologic_n Accuracy: 0.37168141592920356
# ajcc_pathologic_stage Accuracy: 0.5132743362831859
# ajcc_pathologic_t Accuracy: 0.2920353982300885
# ajcc_staging_system_edition Accuracy: 0.7256637168141593
# icd_10_code Accuracy: 0.3185840707964602
# morphology Accuracy: 0.831858407079646
# primary_diagnosis Accuracy: 0.8849557522123894
# prior_malignancy Accuracy: 0.9203539823008849
# prior_treatment Accuracy: 0.9734513274336283
# site_of_resection_or_biopsy Accuracy: 0.3805309734513274
# synchronous_malignancy Accuracy: 0.9557522123893806
# tissue_or_organ_of_origin Accuracy: 0.34513274336283184
# treatment_or_therapy Accuracy: 0.46017699115044247
# treatment_type Accuracy: 0.40707964601769914
# treatment_or_therapy_2 Accuracy: 0.39823008849557523
# treatment_type_2 Accuracy: 0.4247787610619469
# alcohol_history Accuracy: 0.7345132743362832

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('clinical.tsv', sep='\t')


#plt.hist(df['days_to_death'].apply(pd.to_numeric), bins=20)
#plt.hist(df['days_to_death'].replace("'--", np.NaN).apply(pd.to_numeric), bins=20)
#print(df['ethnicity'].value_counts())
#print(df['morphology'].value_counts())
for col in df.columns:
    print(col)
# Out:
# case_id
# case_submitter_id
# age_at_index
# days_to_birth
# days_to_death
# ethnicity
# gender
# race
# vital_status
# year_of_birth
# year_of_death
# age_at_diagnosis
# ajcc_clinical_m
# ajcc_clinical_n
# ajcc_clinical_stage
# ajcc_clinical_t
# ajcc_pathologic_m
# ajcc_pathologic_n
# ajcc_pathologic_stage
# ajcc_pathologic_t
# ajcc_staging_system_edition
# days_to_last_follow_up
# icd_10_code
# morphology
# primary_diagnosis
# prior_malignancy
# prior_treatment
# site_of_resection_or_biopsy
# synchronous_malignancy
# tissue_or_organ_of_origin
# year_of_diagnosis
# treatment_or_therapy
# treatment_type
# treatment_or_therapy_2
# treatment_type_2
# alcohol_history
# cigarettes_per_day
# pack_years_smoked
# years_smoked
